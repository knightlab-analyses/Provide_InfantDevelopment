# %%
# !./effect-size.py --mappings mapping/alldata.tsv --alphas mapping/allshannon.tsv --output alpha_allshannon/
# !./summarize_mdfdr.py --input-fp alpha_allshannon/ --output-fp results_allshannon
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])
# ./summarize_mdfdr.py:85: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'effect_size_values', 'pval_corrected', 'pval'])

# %%
# !./effect-size.py --mappings mapping/alldata.tsv --alphas mapping/allfaith.tsv --output alpha_allfaith/
# !./summarize_mdfdr.py --input-fp alpha_allfaith/ --output-fp results_allfaith
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])
# ./summarize_mdfdr.py:85: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'effect_size_values', 'pval_corrected', 'pval'])

# %%
# !./effect-size.py --mappings mapping/tp1data.tsv --alphas mapping/tp1faith.tsv --output alpha_tp1faith/
# !./summarize_mdfdr.py --input-fp alpha_tp1faith/ --output-fp results_tp1faith
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])

# %%
# !./effect-size.py --mappings mapping/tp1data.tsv --alphas mapping/tp1shannon.tsv --output alpha_tp1shannon/
# !./summarize_mdfdr.py --input-fp alpha_tp1shannon/ --output-fp results_tp1shannon
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])

# %%
# !./effect-size.py --mappings mapping/tp2data.tsv --alphas mapping/tp2faith.tsv --output alpha_tp2faith/
# !./summarize_mdfdr.py --input-fp alpha_tp2faith/ --output-fp results_tp2faith
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])

# %%
# !./effect-size.py --mappings mapping/tp2data.tsv --alphas mapping/tp2shannon.tsv --output alpha_tp2shannon/
# !./summarize_mdfdr.py --input-fp alpha_tp2shannon/ --output-fp results_tp2shannon
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])

# %%
# !./effect-size.py --mappings mapping/tp3data.tsv --alphas mapping/tp3shannon.tsv --output alpha_tp3shannon/
# !./summarize_mdfdr.py --input-fp alpha_tp3shannon/ --output-fp results_tp3shannon
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])

# %%
# !./effect-size.py --mappings mapping/tp3data.tsv --alphas mapping/tp3faith.tsv --output alpha_tp3faith/
# !./summarize_mdfdr.py --input-fp alpha_tp3faith/ --output-fp results_tp3faith
# Out:
# ./summarize_mdfdr.py:43: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   'pairwise_comparisons'])

# %%
# !./effect-size.py --mappings mapping/alldata_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_aitchison_DM.tsv --output beta_allaitchison --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_allaitchison --output-fp beta_results_allaitchison --beta-files

# !./effect-size.py --mappings mapping/alldata_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_jaccard_DM.tsv --output beta_alljaccard --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_alljaccard --output-fp beta_results_alljaccard --beta-files

# !./effect-size.py --mappings mapping/alldata_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_weighted_unifrac_DM.tsv --output beta_allweighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_allweighted --output-fp beta_results_allweighted --beta-files

# !./effect-size.py --mappings mapping/alldata_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_unweighted_unifrac_DM.tsv --output beta_allunweighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_allunweighted --output-fp beta_results_allunweighted --beta-files

# !./effect-size.py --mappings mapping/alldata_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_braycurtis_DM.tsv --output beta_allbray --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_allbray --output-fp beta_results_allbray --beta-files
# Out:
# maps: 1, betas: 1, cols: [22]
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# Pickling array (shape=(345, 345), dtype=float64).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(345, 345), dtype=float64).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(345, 345), dtype=float64).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(345, 345), dtype=float64).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(342,), dtype=object).
# Pickling array (shape=(345, 345), dtype=float64).
# Pickling array (shape=(342,), dtype=object).
# ...

# %%
# !./effect-size.py --mappings mapping/tp1data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_aitchison_DM_aitchison_timepoint_months_9.tsv --output beta_tp1aitchison --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp1aitchison --output-fp beta_results_tp1aitchison --beta-files

# !./effect-size.py --mappings mapping/tp1data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_weighted_unifrac_DM_weighted_unifrac_timepoint_months_9.tsv --output beta_tp1weighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp1weighted --output-fp beta_results_tp1weighted --beta-files

# !./effect-size.py --mappings mapping/tp1data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_unweighted_unifrac_DM_weighted_unifrac_timepoint_months_9.tsv --output beta_tp1unweighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp1unweighted --output-fp beta_results_tp1unweighted --beta-files

# !./effect-size.py --mappings mapping/tp1data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_jaccard_DM_jaccard_timepoint_months_9.tsv --output beta_tp1jaccard --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp1jaccard --output-fp beta_results_tp1jaccard --beta-files

# !./effect-size.py --mappings mapping/tp1data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_braycurtis_DM_braycurtis_timepoint_months_9.tsv --output beta_tp1bray --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp1bray --output-fp beta_results_tp1bray --beta-files
# Out:
# maps: 1, betas: 1, cols: [9]
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# Pickling array (shape=(114, 114), dtype=float64).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(114, 114), dtype=float64).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(114, 114), dtype=float64).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(114, 114), dtype=float64).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(113,), dtype=object).
# Pickling array (shape=(114, 114), dtype=float64).
# Pickling array (shape=(113,), dtype=object).
# ...

# %%
# !./effect-size.py --mappings mapping/tp2data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_aitchison_DM_aitchison_timepoint_months_24.tsv --output beta_tp2aitchison --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp2aitchison --output-fp beta_results_tp2aitchison --beta-files

# !./effect-size.py --mappings mapping/tp2data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_weighted_unifrac_DM_weighted_unifrac_timepoint_months_24.tsv --output beta_tp2weighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp2weighted --output-fp beta_results_tp2weighted --beta-files

# !./effect-size.py --mappings mapping/tp2data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_unweighted_unifrac_DM_weighted_unifrac_timepoint_months_24.tsv --output beta_tp2unweighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp2unweighted --output-fp beta_results_tp2unweighted --beta-files

# !./effect-size.py --mappings mapping/tp2data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_jaccard_DM_jaccard_timepoint_months_24.tsv --output beta_tp2jaccard --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp2jaccard --output-fp beta_results_tp2jaccard --beta-files

# !./effect-size.py --mappings mapping/tp2data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_braycurtis_DM_braycurtis_timepoint_months_24.tsv --output beta_tp2bray --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp2bray --output-fp beta_results_tp2bray --beta-files
# Out:
# maps: 1, betas: 1, cols: [9]
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# Pickling array (shape=(119, 119), dtype=float64).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(119, 119), dtype=float64).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(119, 119), dtype=float64).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(119, 119), dtype=float64).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(118,), dtype=object).
# Pickling array (shape=(119, 119), dtype=float64).
# Pickling array (shape=(118,), dtype=object).
# ...

# %%
# !./effect-size.py --mappings mapping/tp3data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_aitchison_DM_aitchison_timepoint_months_36.tsv --output beta_tp3aitchison --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp3aitchison --output-fp beta_results_tp3aitchison --beta-files

# !./effect-size.py --mappings mapping/tp3data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_weighted_unifrac_DM_weighted_unifrac_timepoint_months_36.tsv --output beta_tp3weighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp3weighted --output-fp beta_results_tp3weighted --beta-files

# !./effect-size.py --mappings mapping/tp3data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_unweighted_unifrac_DM_weighted_unifrac_timepoint_months_36.tsv --output beta_tp3unweighted --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp3unweighted --output-fp beta_results_tp3unweighted --beta-files

# !./effect-size.py --mappings mapping/tp3data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_jaccard_DM_jaccard_timepoint_months_36.tsv --output beta_tp3jaccard --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp3jaccard --output-fp beta_results_tp3jaccard --beta-files

# !./effect-size.py --mappings mapping/tp3data_quan.tsv --betas tab_mGtax_gOTU_min100k_345s/tab_mGtax_gOTU_min100k_345s_braycurtis_DM_braycurtis_timepoint_months_36.tsv --output beta_tp3bray --jobs 32 --permutations 5000
# !./summarize_mdfdr.py --input-fp beta_tp3bray --output-fp beta_results_tp3bray --beta-files
# Out:
# maps: 1, betas: 1, cols: [9]
# [Parallel(n_jobs=32)]: Using backend LokyBackend with 32 concurrent workers.
# Pickling array (shape=(112, 112), dtype=float64).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(112, 112), dtype=float64).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(112, 112), dtype=float64).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(112, 112), dtype=float64).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(111,), dtype=object).
# Pickling array (shape=(112, 112), dtype=float64).
# Pickling array (shape=(111,), dtype=object).
# ...
